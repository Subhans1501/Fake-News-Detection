# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
df=pd.read_csv('D://Study//Semester 5//ML-LAB//Final Project (Fake News Detection)//data//combined_dataset.csv')
print(df['label'].value_counts())
sns.countplot(x='label', data=df)
plt.title('Fake vs Real News Distribution')
plt.show()
text = ' '.join(df[df['label']==0]['text'])
WordCloud(width=800,height=400).generate(text).to_image()
# Out:
# label
# 0    23481
# 1    21417
# Name: count, dtype: int64
# <PIL.Image.Image image mode=RGB size=800x400>
